# %%
import pandas as pd
import numpy as np

# %%
datapointsix = pd.read_csv('D:/aayush/minor/archive/data/GP1_0.6_marker.csv')
datapointseven = pd.read_csv('D:/aayush/minor/archive/data/GP1_0.7_marker.csv')

dataonepointone = pd.read_csv('D:/aayush/minor/archive/data/GP1_1.1_marker.csv')
dataonepointtwo = pd.read_csv('D:/aayush/minor/archive/data/GP1_1.2_marker.csv')

dataonepointsix = pd.read_csv('D:/aayush/minor/archive/data/GP1_1.6_marker.csv')
dataonepointseven = pd.read_csv('D:/aayush/minor/archive/data/GP1_1.7_marker.csv')

# %%
data0 = pd.DataFrame({'secim':np.zeros(12000)})
data1 = pd.DataFrame({'secim':np.ones(12000)})
class2 = []
class3 = []
class4 = []
class5 = []

for i in range(1,12001):
    class2.append(2)
    class3.append(3)
    class4.append(4)
    class5.append(5)

data2 = pd.DataFrame({'secim':class2})
data3 = pd.DataFrame({'secim':class3})
data4 = pd.DataFrame({'secim':class4})
data5 = pd.DataFrame({'secim':class5})
# print(data3)

data5 = pd.concat([dataonepointseven,data5],axis=1)
data4 = pd.concat([dataonepointsix,data4],axis=1)
data3 = pd.concat([dataonepointtwo,data3],axis=1)
data2 = pd.concat([dataonepointone,data2],axis=1)
data1 = pd.concat([datapointseven,data1],axis=1)
data0 = pd.concat([datapointsix,data0],axis=1)

data4 = data4.append(data5,ignore_index=True)
data3 = data3.append(data4,ignore_index=True)
data2 = data2.append(data3,ignore_index=True)
data1 = data1.append(data2,ignore_index=True)
data = data0.append(data1,ignore_index=True)

# data.head()
# Out:
# C:\Users\aayus\AppData\Local\Temp\ipykernel_17212\1698772292.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data4 = data4.append(data5,ignore_index=True)
# C:\Users\aayus\AppData\Local\Temp\ipykernel_17212\1698772292.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data3 = data3.append(data4,ignore_index=True)
# C:\Users\aayus\AppData\Local\Temp\ipykernel_17212\1698772292.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(data3,ignore_index=True)
# C:\Users\aayus\AppData\Local\Temp\ipykernel_17212\1698772292.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
x = data.drop(["secim"],axis=1)
y = data.secim.values
x.head()
# Out:
#     L_FCC_x   L_FM1_x   L_FM2_x   L_FM5_x   R_FCC_x   R_FM1_x   R_FM2_x  \
# 0  1.127087  1.332534  1.328893  1.305142  0.804407  1.017605  1.017485
# 1  1.131831  1.337421  1.333921  1.310700  0.802088  1.015296  1.015148
# 2  1.136807  1.342521  1.339171  1.316510  0.799617  1.012833  1.012659
# 3  1.141961  1.347770  1.344579  1.322506  0.797009  1.010229  1.010033
# 4  1.147230  1.353103  1.350078  1.328615  0.794281  1.007500  1.007287
#
#     R_FM5_x   L_FCC_y   L_FM1_y  ...   R_FM2_y   R_FM5_y   L_FCC_z   L_FM1_z  \
# 0  0.991847  0.575397  0.587244  ...  0.448289  0.396237  0.090627  0.084655
# 1  0.989509  0.575327  0.586249  ...  0.448250  0.396193  0.090195  0.086384
# 2  0.987012  0.575228  0.585174  ...  0.448206  0.396145  0.089767  0.088228
# 3  0.984370  0.575094  0.584023  ...  0.448160  0.396093  0.089354  0.090171
# 4  0.981602  0.574925  0.582801  ...  0.448109  0.396038  0.088963  0.092198
#
#     L_FM2_z   L_FM5_z   R_FCC_z   R_FM1_z   R_FM2_z   R_FM5_z
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
print('Accuracy of dec tree in test data is:',dt.score(x_test,y_test))
# Out:
# Accuracy of dec tree in test data is: 0.9390277777777778

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100,random_state=1)
rf.fit(x_train,y_train)
print('Random Forest accuracy on test data is : ',rf.score(x_test,y_test))
# Out:
# Random Forest accuracy on test data is :  0.9946759259259259
